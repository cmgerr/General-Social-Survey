# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib
matplotlib.style.use('ggplot')
import seaborn as sns

# %%
# import cleaned data
df = pd.read_csv('../Data/gss_subset_cleaned.csv')

# %%
# check dtypes and nulls in current csv
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59599 entries, 0 to 59598
# Data columns (total 29 columns):
# year        59599 non-null float64
# marital     59575 non-null object
# divorce     59346 non-null object
# sibs        57913 non-null float64
# childs      59410 non-null float64
# age         59599 non-null float64
# educ        59434 non-null float64
# paeduc      42058 non-null float64
# maeduc      49200 non-null float64
# speduc      30774 non-null float64
# sex         59599 non-null object
# hompop      59593 non-null float64
# babies      59280 non-null float64
# preteen     59253 non-null float64
# teens       59327 non-null float64
# adults      59535 non-null float64
# earnrs      59060 non-null float64
# income      52072 non-null float64
# polviews    52491 non-null float64
# happy       54851 non-null float64
# health      44136 non-null float64
# weekswrk    28181 non-null float64
# satjob      43172 non-null float64
# satfin      54986 non-null float64
# goodlife    18127 non-null float64
# dwelling    46699 non-null float64
# dwelown     59200 non-null float64
# hhrace      52686 non-null float64
# famgen      54243 non-null float64
# dtypes: float64(26), object(3)
# memory usage: 13.2+ MB

# %%
# delete "Unnamed: 0" column
del df['Unnamed: 0']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-de8c02838cc3> in <module>()
#       1 # delete "Unnamed: 0" column
# ----> 2 del df['Unnamed: 0']
#
# /Users/canadasfinest189/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __delitem__(self, key)
#    1599             # there was no match, this call should raise the appropriate
#    1600             # exception:
# -> 1601             self._data.delete(key)
#    1602
#    1603         # delete from the caches
#
# /Users/canadasfinest189/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in delete(self, item)
#    3282         Delete selected item (items if non-unique) in-place.
#    3283         """
# -> 3284         indexer = self.items.get_loc(item)
#    3285
#    3286         is_deleted = np.zeros(self.shape[0], dtype=np.bool_)
#
# /Users/canadasfinest189/anaconda/lib/python2.7/site-packages/pandas/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    1876                 return self._engine.get_loc(key)
#    1877             except KeyError:
# -> 1878                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    1879
#    1880         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4027)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3891)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12408)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12359)()
#
# KeyError: 'Unnamed: 0'

# %%
# change divorce to indicator variable (1 = has divorced / 0 = never divorced)
df['divorce'] = (df.divorce=='yes').astype(int)

# %%
# list categorical columns and numerical columns for filtering
categorical_cols = ['marital', 'sex']
numerical_cols = df.columns.drop(categorical_cols)

# %%
# look at histogram for each categorical 
for col in df[categorical_cols]:
    df[col].value_counts().plot(kind='bar')
    plt.title(col+" distribution")
    plt.show()

# look at hist for each numerical
for col in df[numerical_cols]:
    plt.hist(df[col])
    plt.title(col+" distribution")
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-e78637b43381> in <module>()
#       7 # look at hist for each numerical
#       8 for col in df[numerical_cols]:
# ----> 9     plt.hist(df[col])
#      10     plt.title(col+" distribution")
#      11     plt.show()
#
# /Users/canadasfinest189/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.pyc in hist(x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, hold, data, **kwargs)
#    2956                       histtype=histtype, align=align, orientation=orientation,
#    2957                       rwidth=rwidth, log=log, color=color, label=label,
# -> 2958                       stacked=stacked, data=data, **kwargs)
#    2959     finally:
#    2960         ax.hold(washold)
#
# /Users/canadasfinest189/anaconda/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1810                     warnings.warn(msg % (label_namer, func.__name__),
#    1811                                   RuntimeWarning, stacklevel=2)
# -> 1812             return func(ax, *args, **kwargs)
#    1813         pre_doc = inner.__doc__
#    1814         if pre_doc is None:
#
# /Users/canadasfinest189/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in hist(self, x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6008             # this will automatically overwrite bins,
#    6009             # so that each histogram uses the same bins
# -> 6010             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6011             m = m.astype(float)  # causes problems later if it's an int
#    6012             if mlast is None:
#
# /Users/canadasfinest189/anaconda/lib/python2.7/site-packages/numpy/lib/function_base.pyc in histogram(a, bins, range, normed, weights, density)
#     500     if mn > mx:
#     501         raise ValueError(
# --> 502             'max must be larger than min in range parameter.')
#     503     if not np.all(np.isfinite([mn, mx])):
#     504         raise ValueError(
#
# ValueError: max must be larger than min in range parameter.

# %%
# look at happiness by age for male and female respondents
ax1 = plt.subplot(111)
df[df['sex']=='Male'].groupby(['age']).agg({'happy':
    np.mean}).plot(color='b', xlim = (0,90), ylim = (1.6,2),
    ax = ax1, legend = False)
df[df['sex']=='Female'].groupby(['age']).agg({'happy':
    np.mean}).plot(color='g',xlim = (0,90),
    ax = ax1)
plt.legend(['Male Avg Happiness', 'Female Avg Happiness'],
    bbox_to_anchor = (0.4,1))
plt.title('Happiness by age (lower is happier)')
plt.show()

# %%
# plot happiness by marital status
ax2 = plt.subplot(111)
df.groupby('marital').agg({'happy': np.mean}).plot(kind='bar', legend=False, ax=ax2)
plt.title('Average Happiness by Marital Status')
plt.show()

# %%
# average happiness by education level
ax3 = plt.subplot(111)
df.groupby('educ').agg({'happy': np.mean}).plot(kind='line', legend=False, ax=ax3)
plt.title('Average Happiness by Education Level')
plt.show()

# %%
# self reported happiness over time
sns.factorplot(
    x = 'year',
    y = 'happy',
    data = df,
    hue = 'sex',
    size = 10
    )

# %%
# happiness by marital status: violinplot
sns.factorplot(
    x = 'marital',
    y = 'happy',
    data = df,
    hue = 'sex',
    size = 10,
    kind='violin'
    )

# %%
# look at happiness by number of children
sns.factorplot(
    x = 'childs',
    y = 'happy',
    data = df,
    hue = 'sex',
    size = 10,
    kind='bar'
    )

# %%
# look at happiness by number of children < 6
sns.factorplot(
    x = 'babies',
    y = 'happy',
    data = df,
    hue = 'sex',
    size = 10,
    kind='bar'
    )

# %%
# look at correlations in data
sns.heatmap(df.drop(categorical_cols, axis=1).corr())

# %%
# look at happiness by political views (from 1: extremely liberal to 7: extremely conservative)
sns.factorplot(
    x = 'polviews',
    y = 'happy',
    data = df,
    size = 7,
    kind='bar'
    )

# %%
# look at political views (from 1: extremely liberal to 7: extremely conservative) by age
sns.factorplot(
    x = 'age',
    y = 'polviews',
    data = df,
    size = 7,
    kind='point',
    hue = 'sex'
    )

# %%
def decade_sorter(x):
    if x >= 1970 and x <1980:
        return 1
    elif x >=1980 and x < 1990:
        return 2
    elif x >=1990 and x < 2000:
        return 3
    elif x >= 2000 and x < 2010:
        return 4
    elif x >= 2010 and x < 2020:
        return 5

# %%
df['decade'] = df['year'].apply(decade_sorter)

# %%
sns.factorplot(
    x = 'satjob',
    y = 'happy', 
    data = df, 
    kind = 'point', 
    hue = 'decade')

# %%
sns.factorplot(
    x = 'satfin',
    y = 'happy', 
    data = df, 
    kind = 'point', 
    hue = 'decade')
